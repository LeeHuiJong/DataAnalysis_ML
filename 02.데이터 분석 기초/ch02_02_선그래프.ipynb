# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeHuiJong/SkillTreePython-DataAnalysis/blob/main/ch02_02_%EC%84%A0%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ch02.02. 선그래프
#
# ---
# * 날짜:
# * 이름:

# %% [markdown]
# ##  개념정리
# ---
#
# ```
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# plt.rcParams['figure.figsize'] = [6, 4]
# plt.style.use('seaborn-white')
# sns.set_style('white')
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [6, 4] # 가로 세로 그림의 디폴트 사이즈
plt.style.use('seaborn-white') # 스타일 6개 중에 하나를 지정
sns.set_style('white')

# %% [markdown]
# ### **01. Matplotlib 으로 그리기**
# ---

# %% [markdown]
# #### **| 기본사용**
#
# ```
# xs = ['Jan', 'Fab', 'Mar', 'Apr', 'May', 'Jun']
# nums = [35, 40, 35, 40, 55, 45]
# plt.bar(xs, nums)
# plt.show()
# ```

# %%
xs = ['Jan', 'Fab', 'Mar', 'Apr', 'May', 'Jun']
nums = [35, 40, 35, 40, 55, 45]

plt.plot(xs, nums)

# %% [markdown]
# #### **| 옵션**
#
# ```
# plt.plot(data,
#         color=색,
#         linestyle=선스타일,
#         marker=마커,
#         markerfacecolor=마커색
#         markersize=마커사이즈
#         alpha=투명도 (0~1),
#         label = 레이블,
# ```

# %%
plt.plot(xs, nums, marker='o', label='sales')
plt.legend()

# %% [markdown]
# ### **02. Seaborn 으로 그리기**
# ---

# %% [markdown]
# #### **| 기본사용**
#
# ```
# sns.lineplot(x=xs, y=nums)
# plt.show()
# ```

# %%
sns.lineplot(x=xs, y=nums)    # 엑셀 파일을 뽑아올때 더 간결하게 사용가능
plt.show()

# %% [markdown]
# #### **| DataFrame 사용**
# ---

# %% [markdown]
# * 데이터 프레임을 만들어 줍니다.

# %%
xs, nums

df=pd.DataFrame([xs, nums]).T
df.columns=['Month','Count']
df
# Out:
#   Month Count
# 0   Jan    35
# 1   Fab    40
# 2   Mar    35
# 3   Apr    40
# 4   May    55
# 5   Jun    45

# %% [markdown]
# * 데이터프레임에서 기본적으로 플롯을 제공합니다.
#
#
# ```
# df.plot(x=x,y=y)
# ```

# %%
df.plot(x='Month', y='Count')

# %% [markdown]
# * 데이터프레임 기반으로 seaborn을 사용합니다.
#
#
# ```
# sns.lineplot(data=df,x=x, y=y')
# ```

# %%
#sns.lineplot(x=xs, y=nums)
sns.lineplot(data=df, x='Month', y='Count')

# %% [markdown]
# ## 실습

# %% [markdown]
# ### **01. 플롯 분할**
# ---

# %%
x = np.linspace(-5,5,1000)
def func2(a):  
  y = a*(x**2)
  return y

plt.plot(x,func2(2))

# %%
x = np.linspace(-5,5,1000)
def func2(a):  
  y = a*(x**2)
  return y

plt.plot(x,func2(-1))

# %%
x = np.linspace(-5,5,1000)
def func2(a):  
  y = a*(x**2)
  return y

plt.plot(x,func2(-2))

# %%
a=1

x = np.linspace(-5,5,1000) # -5 에서 5까지 1000개의 데이터로 나눔
def func2(a):  
  y = a*(x**2)
  return y

# 왼쪽
plt.subplot(1,2,1) # (행의개수, 열의개수, 위치)
plt.plot(x,func2(1)) # y= x**2
plt.plot(x,func2(2)) # y= 2x^2

# 오른쪽
plt.subplot(1,2,2)
plt.plot(x,func2(-1)) # y= -x^2
plt.plot(x,func2(-2)) # y= -2x^2

# %% [markdown]
# ### **02. 눈금 공유**
# ---

# %%
t= np.arange(0.01,5,0.01)  # 0.01 부터 5까지 0.01 씩 증가
s1 = np.sin(t*np.pi)
s2 = np.sin(t**np.pi)
s3 = np.exp(-t)

ax1 = plt.subplot(3,1,1)
plt.plot(t,s1)
plt.tick_params('x', labelbottom=False)# 눈금 지우기

plt.subplot(3,1,2, sharex=ax1)  # sharex= x  x를 다른 축으로 정의해 준다.
plt.plot(t,s2)
plt.tick_params('x', labelbottom=False)

plt.subplot(3,1,3, sharex=ax1) # 축공유
plt.plot(t,s3)

# %% [markdown]
# ## 과제

# %% [markdown]
# ### **01. 로그함수와 지수함수 그리기**
# ---

# %%
x = np.linspace(0,-5,1000) # -5 에서 5까지 1000개의 데이터로 나눔
def func2(a):  
  y = np.exp(-x)
  return y
plt.plot(x,func2(1))

# %%
x = np.linspace(0,5,1000) # -5 에서 5까지 1000개의 데이터로 나눔
def func2(a):  
  y = np.log(x)
  return y
plt.plot(x,func2(1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x = np.linspace(0,5,1000) # -5 에서 5까지 1000개의 데이터로 나눔
def func2(a):  
  y = np.exp(x)
  return y
plt.plot(x,func2(1))

# %%
p = np.linspace(0,5,1000) 
s4 = np.exp(p)
plt.plot(-s4)

# %%
t= np.arange(0,10,0.1)  # 0.01 부터 5까지 0.01 씩 증가
s1 = np.exp(t)
s2 = np.exp(t)
s3 = np.exp(-t)
s4 = np.log(t)

ax1 = plt.subplot(4,1,1)
plt.plot(t,s1)
plt.tick_params('x', labelbottom=False)# 눈금 지우기

plt.subplot(4,1,2, sharex=ax1)
plt.plot(t,-s2)
plt.tick_params('x', labelbottom=False)

plt.subplot(4,1,3, sharex=ax1)
plt.plot(t,s3)
plt.tick_params('x', labelbottom=False)

plt.subplot(4,1,4, sharex=ax1)
plt.plot(t,s4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
t= np.arange(0,10,0.1)  # 0.01 부터 5까지 0.01 씩 증가
s1 = np.exp(t)
s2 = np.exp(t)
s3 = np.exp(-t)
s4 = np.log(t)

ax1 = plt.subplot(4,2,1)
plt.plot(t,s1)
plt.tick_params('x', labelbottom=False)# 눈금 지우기

plt.subplot(4,2,3, sharex=ax1)
plt.plot(t,-s2)

plt.subplot(4,2,2, sharex=ax1)
plt.plot(t,s3)
plt.tick_params('x', labelbottom=False)

plt.subplot(4,2,4, sharex=ax1)
plt.plot(t,s4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %% [markdown]
# ### **02. 램덤값 비교하기**
# ---
#
# - 넘파이로 표준정규분포를 따르는 50개의 데이터를 총 세개 추출하세요.
# - 세개의 데이터를 3 x 1 플롯으로 그리세요
# - 세개의 플롯의 눈금을 모두 공유하세요.

# %%
a1= np.random.randn(50)
a2= np.random.randn(50)
a3= np.random.randn(50)

ax1 = plt.subplot(3,1,1) 
plt.plot(a1)
plt.tick_params('x', labelbottom=False)

plt.subplot(3,1,2,sharex=ax1) 
plt.plot(a2)
plt.tick_params('x', labelbottom=False)

plt.subplot(3,1,3,sharex=ax1) 
plt.plot(a3)

# %% [markdown]
# ### **02. flights 데이터**
# ---

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
df['passengers'].groupby(df['year']).median()
# Out:
# year
# 1949    125.0
# 1950    137.5
# 1951    169.0
# 1952    192.0
# 1953    232.0
# 1954    231.5
# 1955    272.0
# 1956    315.0
# 1957    351.5
# 1958    360.5
# 1959    406.5
# 1960    461.0
# Name: passengers, dtype: float64

# %%
df['passengers'].groupby(df['year']).mean()
# Out:
# year
# 1949    126.666667
# 1950    139.666667
# 1951    170.166667
# 1952    197.000000
# 1953    225.000000
# 1954    238.916667
# 1955    284.000000
# 1956    328.250000
# 1957    368.416667
# 1958    381.000000
# 1959    428.333333
# 1960    476.166667
# Name: passengers, dtype: float64

# %%
a=df['passengers'].groupby(df['year']).mean() # 각 연도의 평균과 그룹한 값
plt.plot(a,marker="o")

# %%
b=df['passengers'].groupby(df['year']).std() # 각 연도의 표준편차와 그룹한 값
plt.plot(b,marker="o")

# %%
c=df['passengers'].groupby(df['year']).min() # 각 연도의 최소값과 그룹한 값
plt.plot(c,marker="o")

# %%
d=df['passengers'].groupby(df['year']).max() # 각 연도의 최대값과 그룹한 값
plt.plot(d,marker="o")

# %%
e=df['passengers'].groupby(df['year']).median() # 각 연도의 중간값과 그룹한 값
plt.plot(e,marker="o")
